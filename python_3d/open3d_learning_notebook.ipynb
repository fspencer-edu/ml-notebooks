# %% [markdown]
# # Open3D Learning Notebook
#
# Point clouds, meshes, and geometry processing.

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# pip install open3d numpy jupyter
# jupyter notebook
# ```

# %% [markdown]
# ## Imports

# %%
import open3d as o3d
import numpy as np
# Out:
# /opt/homebrew/anaconda3/envs/mlenv/lib/python3.11/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %% [markdown]
# ## Point cloud and mesh

# %%
points = np.random.rand(300, 3)
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(points)
o3d.visualization.draw_geometries([pcd])

mesh = o3d.geometry.TriangleMesh.create_sphere(radius=1.0)
mesh.compute_vertex_normals()
o3d.visualization.draw_geometries([mesh])
# Out:
# 2026-03-15 00:22:10.779 python[2425:1724698] +[IMKClient subclass]: chose IMKClient_Modern
# 2026-03-15 00:22:10.779 python[2425:1724698] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %% [markdown]
# ## Useful objects

# %%
reference = {
    "Geometry": ["PointCloud", "TriangleMesh", "LineSet"],
    "Creation": ["create_sphere", "create_box", "create_coordinate_frame"],
    "Processing": ["translate", "rotate", "scale", "paint_uniform_color", "estimate_normals"],
    "Visualization": ["draw_geometries"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
# Out:
# Geometry:
# PointCloud, TriangleMesh, LineSet
#
# Creation:
# create_sphere, create_box, create_coordinate_frame
#
# Processing:
# translate, rotate, scale, paint_uniform_color, estimate_normals
#
# Visualization:
# draw_geometries
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
