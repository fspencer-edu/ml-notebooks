# %% [markdown]
# # Ursina Learning Notebook
#
# Beginner-friendly Python 3D engine.

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# pip install ursina jupyter
# jupyter notebook
# ```

# %% [markdown]
# ## Basic app structure

# %%
game_code = '''
from ursina import *

app = Ursina()
cube = Entity(model='cube', color=color.orange, scale=2)
camera.position = (0, 0, -8)
app.run()
'''
print(game_code)

# %% [markdown]
# ## Useful objects

# %%
reference = {
    "Core": ["Ursina", "Entity", "camera", "color", "EditorCamera"],
    "Entity args": ["model", "texture", "color", "position", "rotation", "scale"],
    "Loop": ["update", "app.run"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
