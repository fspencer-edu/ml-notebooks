# %% [markdown]
# # Dask Learning Notebook
#
#
# This notebook shows how to use **Dask** for parallel arrays, DataFrames, and delayed tasks.

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# pip install dask[dataframe] pandas numpy jupyter
# jupyter notebook
# ```

# %% [markdown]
# ## Dask DataFrame

# %%
import dask.dataframe as dd
import pandas as pd
pdf = pd.DataFrame({"x": range(100), "y": range(100, 200)})
ddf = dd.from_pandas(pdf, npartitions=4)
print(ddf)
print(ddf.head())

# %% [markdown]
# ## Computation

# %%
print(ddf["y"].mean().compute())
print(ddf.groupby(ddf["x"] % 2)["y"].mean().compute())

# %% [markdown]
# ## Delayed

# %%
from dask import delayed

@delayed
def square(x):
    return x * x

tasks = [square(i) for i in range(5)]
print(tasks)
print(delayed(sum)(tasks).compute())

# %% [markdown]
# ## Useful pieces

# %%
reference = {
    "DataFrame": ["from_pandas", "read_csv", "compute", "groupby"],
    "Delayed": ["delayed"],
    "Parallel work": ["npartitions", "compute"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
