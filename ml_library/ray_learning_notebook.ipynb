# %% [markdown]
# # Ray Learning Notebook
#
#
# This notebook shows how to use **Ray** for parallel Python tasks and actors.
#
# distributed ML training
#
# reinforcement learning
#
# microservices

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# pip install ray jupyter
# jupyter notebook
# ```

# %% [markdown]
# ## Init and remote functions

# %%
import ray
ray.init(ignore_reinit_error=True)

@ray.remote
def square(x):
    return x * x

futures = [square.remote(i) for i in range(5)]
print(ray.get(futures))
# Out:
# /opt/homebrew/anaconda3/envs/mlenv/lib/python3.11/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# 2026-03-14 23:40:47,452	INFO worker.py:2013 -- Started a local Ray instance.
# [0, 1, 4, 9, 16]
# /opt/homebrew/anaconda3/envs/mlenv/lib/python3.11/site-packages/ray/_private/worker.py:2052: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(

# %% [markdown]
# ## Actors

# %%
@ray.remote
class Counter:
    def __init__(self):
        self.value = 0
    def inc(self):
        self.value += 1
        return self.value

c = Counter.remote()
print(ray.get(c.inc.remote()))
print(ray.get(c.inc.remote()))
# Out:
# 1
# 2

# %% [markdown]
# ## Useful pieces

# %%
reference = {
    "Core": ["init", "remote", "get", "put"],
    "Patterns": ["remote functions", "actors"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
# Out:
# Core:
# init, remote, get, put
#
# Patterns:
# remote functions, actors
