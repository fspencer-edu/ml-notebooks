# %% [markdown]
# # Flask Learning Notebook
#
#
# This notebook shows how to use **Flask** to build simple web apps and APIs.

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# pip install flask jupyter
# jupyter notebook
# ```

# %% [markdown]
# ## Basic app

# %%
app_code = '''
from flask import Flask, jsonify, request

app = Flask(__name__)

@app.route("/")
def home():
    return "Hello Flask"

@app.route("/api/echo", methods=["POST"])
def echo():
    data = request.get_json()
    return jsonify(data)

if __name__ == "__main__":
    app.run(debug=True)
'''
print(app_code)

# %% [markdown]
# ## Useful pieces

# %%
reference = {
    "Core": ["Flask", "route", "run"],
    "Request/response": ["request", "jsonify", "render_template"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
