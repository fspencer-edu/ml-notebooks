# %% [markdown]
# # fastai Learning Notebook
#
#
# This notebook shows how to use **fastai** for quick deep learning workflows.
#
# Purpose: Simplified deep learning on top of PyTorch
#
# What it provides:
#
# high-level APIs
#
# automatic training loops
#
# pretrained models
#
# Used for:
#
# image classification
#
# NLP
#
# tabular deep learning

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# pip install fastai jupyter
# jupyter notebook
# ```

# %% [markdown]
# ## Imports

# %%
from fastai.tabular.all import *
from sklearn.datasets import load_iris
import pandas as pd
print("fastai imported successfully.")
# Out:
# /opt/homebrew/anaconda3/envs/mlenv/lib/python3.11/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# fastai imported successfully.

# %% [markdown]
# ## Tabular workflow

# %%
iris = load_iris(as_frame=True)
df = iris.frame
df["target"] = df["target"].map(dict(enumerate(iris.target_names)))
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# ## DataLoaders and Learner

# %%
dls = TabularDataLoaders.from_df(
    df, path='.', y_names='target', cat_names=[],
    cont_names=iris.feature_names, procs=[Categorify, FillMissing, Normalize], bs=16
)
learn = tabular_learner(dls, metrics=accuracy)
learn.fit(5)
# Out:
# /opt/homebrew/anaconda3/envs/mlenv/lib/python3.11/site-packages/fastai/torch_core.py:154: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:219.)
#   else as_tensor(x.values, **kwargs) if isinstance(x, (pd.Series, pd.DataFrame))
# <style>
#     progress { appearance: none; border: none; border-radius: 4px; width: 300px;
#         height: 20px; vertical-align: middle; background: #e0e0e0; }
#
#     progress::-webkit-progress-bar { background: #e0e0e0; border-radius: 4px; }
#     progress::-webkit-progress-value { background: #2196F3; border-radius: 4px; }
# ...

# %% [markdown]
# ## Prediction and interpretation

# %%
row = df.iloc[0]
pred, pred_idx, probs = learn.predict(row)
print("Prediction:", pred)
print("Probabilities:", probs)
# Out:
# Prediction:    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0          -0.882099          0.978004          -1.315548         -1.299089
#
#    target
# 0     0.0
# Probabilities: tensor([0.9924, 0.0019, 0.0058])

# %% [markdown]
# ## Useful classes and methods

# %%
reference = {
    "Core": ["TabularDataLoaders", "tabular_learner", "Learner"],
    "Methods": ["fit", "fine_tune", "predict", "show_results", "save", "load"],
    "Tabular helpers": ["Categorify", "FillMissing", "Normalize"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
# Out:
# Core:
# TabularDataLoaders, tabular_learner, Learner
#
# Methods:
# fit, fine_tune, predict, show_results, save, load
#
# Tabular helpers:
# Categorify, FillMissing, Normalize
