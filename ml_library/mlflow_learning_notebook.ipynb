# %% [markdown]
# # MLflow Learning Notebook
#
#
# This notebook shows how to use **MLflow** for experiment tracking and model logging.
#
# parameters
#
# metrics
#
# models
#
# artifacts
#
# Useful for:
#
# research
#
# production ML

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# pip install mlflow scikit-learn pandas jupyter
# jupyter notebook
# ```

# %% [markdown]
# ## Basic tracking

# %%
import mlflow
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

with mlflow.start_run():
    model = RandomForestClassifier(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    acc = accuracy_score(y_test, pred)
    mlflow.log_param("n_estimators", 100)
    mlflow.log_metric("accuracy", acc)
    mlflow.sklearn.log_model(model, "model")
print("Run logged. Start UI with: mlflow ui")
# Out:
# /opt/homebrew/anaconda3/envs/mlenv/lib/python3.11/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# 2026/03/14 23:43:06 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/03/14 23:43:06 INFO mlflow.store.db.utils: Updating database tables
# 2026/03/14 23:43:07 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/03/14 23:43:07 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Run logged. Start UI with: mlflow ui

# %% [markdown]
# ## Useful pieces

# %%
reference = {
    "Tracking": ["start_run", "log_param", "log_metric", "log_artifact"],
    "Model logging": ["mlflow.sklearn.log_model", "mlflow.pyfunc.load_model"],
    "UI": ["mlflow ui"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
# Out:
# Tracking:
# start_run, log_param, log_metric, log_artifact
#
# Model logging:
# mlflow.sklearn.log_model, mlflow.pyfunc.load_model
#
# UI:
# mlflow ui
