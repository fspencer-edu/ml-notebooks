# %% [markdown]
# # Stable-Baselines3 Learning Notebook
#
#
# This notebook shows how to use **Stable-Baselines3** with Gymnasium.

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# pip install stable-baselines3 gymnasium jupyter
# jupyter notebook
# ```

# %% [markdown]
# ## Train PPO on CartPole

# %%
import gymnasium as gym
from stable_baselines3 import PPO

env = gym.make("CartPole-v1")
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=1000)

obs, info = env.reset()
for _ in range(5):
    action, _states = model.predict(obs)
    obs, reward, terminated, truncated, info = env.step(action)
    print(reward)
    if terminated or truncated:
        obs, info = env.reset()

# %% [markdown]
# ## Useful pieces

# %%
reference = {
    "Algorithms": ["PPO", "A2C", "DQN", "SAC", "TD3"],
    "Methods": ["learn", "predict", "save", "load"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
