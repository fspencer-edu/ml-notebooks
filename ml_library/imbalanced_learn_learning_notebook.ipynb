# %% [markdown]
# # imbalanced-learn Learning Notebook
#
#
# This notebook shows how to use **imbalanced-learn** for SMOTE and resampling.

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# pip install imbalanced-learn scikit-learn pandas numpy jupyter
# jupyter notebook
# ```

# %% [markdown]
# ## Create imbalanced data

# %%
from sklearn.datasets import make_classification
from collections import Counter

X, y = make_classification(n_samples=1000, n_features=20, weights=[0.9, 0.1], random_state=42)
print("Original:", Counter(y))
# Out:
# Original: Counter({np.int64(0): 897, np.int64(1): 103})

# %% [markdown]
# ## SMOTE

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X, y)
print("After SMOTE:", Counter(y_res))
# Out:
# After SMOTE: Counter({np.int64(0): 897, np.int64(1): 897})

# %% [markdown]
# ## Pipeline example

# %%
from imblearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

pipe = Pipeline([
    ("smote", SMOTE(random_state=42)),
    ("model", LogisticRegression(max_iter=200))
])
pipe.fit(X, y)
print(pipe)
# Out:
# Pipeline(steps=[('smote', SMOTE(random_state=42)),
#                 ('model', LogisticRegression(max_iter=200))])

# %% [markdown]
# ## Useful pieces

# %%
reference = {
    "Oversampling": ["SMOTE", "RandomOverSampler"],
    "Undersampling": ["RandomUnderSampler"],
    "Pipelines": ["Pipeline"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
# Out:
# Oversampling:
# SMOTE, RandomOverSampler
#
# Undersampling:
# RandomUnderSampler
#
# Pipelines:
# Pipeline
