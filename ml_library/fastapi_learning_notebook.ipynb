# %% [markdown]
# # FastAPI Learning Notebook
#
#
# This notebook shows how to use **FastAPI** to build APIs.

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# pip install fastapi uvicorn pydantic jupyter
# jupyter notebook
# ```

# %% [markdown]
# ## Basic app

# %%
app_code = '''
from fastapi import FastAPI
from pydantic import BaseModel

app = FastAPI()

class Item(BaseModel):
    name: str
    price: float

@app.get("/")
def home():
    return {"message": "Hello FastAPI"}

@app.post("/items")
def create_item(item: Item):
    return {"item": item.model_dump()}
'''
print(app_code)
# Out:
# from fastapi import FastAPI
# from pydantic import BaseModel
#
# app = FastAPI()
#
# class Item(BaseModel):
#     name: str
#     price: float
#
# @app.get("/")
# def home():
#     return {"message": "Hello FastAPI"}
#
# @app.post("/items")
# def create_item(item: Item):
#     return {"item": item.model_dump()}

# %% [markdown]
# ## Run server

# %%
print("Save the code as app.py, then run:")
print("uvicorn app:app --reload")
# Out:
# Save the code as app.py, then run:
# uvicorn app:app --reload

# %% [markdown]
# ## Useful pieces

# %%
reference = {
    "Core": ["FastAPI", "get", "post", "put", "delete"],
    "Validation": ["BaseModel"],
    "Run": ["uvicorn"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
# Out:
# Core:
# FastAPI, get, post, put, delete
#
# Validation:
# BaseModel
#
# Run:
# uvicorn
