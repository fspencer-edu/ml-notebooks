# %% [markdown]
# # TPOT Learning Notebook
#
#
# This notebook shows how to use **TPOT** for AutoML pipelines.

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# pip install tpot scikit-learn jupyter
# jupyter notebook
# ```

# %% [markdown]
# ## Basic TPOT usage

# %%
from tpot import TPOTClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

tpot = TPOTClassifier(generations=2, population_size=10, verbosity=2, random_state=42)
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))
tpot.export("tpot_best_pipeline.py")
# Out:
# /opt/homebrew/anaconda3/envs/mlenv/lib/python3.11/site-packages/stopit/__init__.py:10: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /opt/homebrew/anaconda3/envs/mlenv/lib/python3.11/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       6 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
#       8 tpot = TPOTClassifier(generations=2, population_size=10, verbosity=2, random_state=42)
# ----> 9 tpot.fit(X_train, y_train)
# ...

# %% [markdown]
# ## Useful pieces

# %%
reference = {
    "Core": ["TPOTClassifier", "TPOTRegressor"],
    "Methods": ["fit", "score", "predict", "export"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
# Out:
# Core:
# TPOTClassifier, TPOTRegressor
#
# Methods:
# fit, score, predict, export
