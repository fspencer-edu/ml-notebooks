# %% [markdown]
# # BentoML Learning Notebook
#
#
# This notebook shows how to use **BentoML** for packaging and serving ML models.
# Deploy ML models
#
# Features:
#
# packaging models
#
# model serving
#
# Docker integration

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# pip install bentoml scikit-learn jupyter
# jupyter notebook
# ```

# %% [markdown]
# ## Basic service example

# %%
service_code = '''
import bentoml
from bentoml.io import JSON

iris_clf = bentoml.sklearn.get("iris_clf:latest").to_runner()
svc = bentoml.Service("iris_service", runners=[iris_clf])

@svc.api(input=JSON(), output=JSON())
def predict(input_data):
    pred = iris_clf.run([input_data["features"]])
    return {"prediction": pred.tolist()}
'''
print(service_code)
# Out:
# import bentoml
# from bentoml.io import JSON
#
# iris_clf = bentoml.sklearn.get("iris_clf:latest").to_runner()
# svc = bentoml.Service("iris_service", runners=[iris_clf])
#
# @svc.api(input=JSON(), output=JSON())
# def predict(input_data):
#     pred = iris_clf.run([input_data["features"]])
#     return {"prediction": pred.tolist()}

# %% [markdown]
# ## Useful pieces

# %%
reference = {
    "Core": ["Service", "api", "save_model", "get"],
    "Serving": ["serve", "build"],
    "Framework support": ["sklearn", "xgboost", "pytorch", "tensorflow"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
# Out:
# Core:
# Service, api, save_model, get
#
# Serving:
# serve, build
#
# Framework support:
# sklearn, xgboost, pytorch, tensorflow
