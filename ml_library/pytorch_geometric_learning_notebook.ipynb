# %% [markdown]
# # PyTorch Geometric Learning Notebook
#
#
# This notebook shows how to use **PyTorch Geometric** for graph neural networks.

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# # Install PyTorch first, then install PyG following the official wheel instructions.
# pip install torch-geometric
# jupyter notebook
# ```

# %% [markdown]
# ## Graph data object

# %%
import torch
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv

x = torch.tensor([[1.], [2.], [3.]], dtype=torch.float)
edge_index = torch.tensor([[0, 1, 1, 2], [1, 0, 2, 1]], dtype=torch.long)
data = Data(x=x, edge_index=edge_index)
print(data)

# %% [markdown]
# ## Simple GCN

# %%
import torch.nn.functional as F
from torch import nn

class GCN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = GCNConv(1, 4)
        self.conv2 = GCNConv(4, 2)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index).relu()
        x = self.conv2(x, edge_index)
        return x

model = GCN()
out = model(data)
print(out)

# %% [markdown]
# ## Useful pieces

# %%
reference = {
    "Data": ["Data", "Dataset", "DataLoader"],
    "Layers": ["GCNConv", "GATConv", "SAGEConv"],
    "Training": ["forward", "optimizer", "loss"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
