# %% [markdown]
# # Hugging Face Transformers Learning Notebook
#
#
# This notebook shows how to use **Transformers** for tokenization, pipelines,
# text classification, and embeddings.

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# pip install transformers datasets torch jupyter
# jupyter notebook
# ```

# %% [markdown]
# ## Imports

# %%
from transformers import pipeline, AutoTokenizer, AutoModel, AutoModelForSequenceClassification
import torch
print("Transformers imported successfully.")
# Out:
# /opt/homebrew/anaconda3/envs/mlenv/lib/python3.11/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# Transformers imported successfully.

# %% [markdown]
# ## Pipeline usage

# %%
classifier = pipeline("sentiment-analysis")
print(classifier("I love studying machine learning."))
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/homebrew/anaconda3/envs/mlenv/lib/python3.11/site-packages/transformers/activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ...

# %% [markdown]
# ## Tokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")
encoded = tokenizer("Hello from Hugging Face Transformers!", return_tensors="pt")
print(encoded)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# {'input_ids': tensor([[  101,  7592,  2013, 17662,  2227, 19081,   999,   102]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1, 1, 1]])}

# %% [markdown]
# ## Model forward pass

# %%
model = AutoModel.from_pretrained("distilbert-base-uncased")
with torch.no_grad():
    outputs = model(**encoded)
print(outputs.last_hidden_state.shape)
# Out:
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# torch.Size([1, 8, 768])

# %% [markdown]
# ## Sequence classification model

# %%
clf_model = AutoModelForSequenceClassification.from_pretrained("distilbert-base-uncased", num_labels=2)
print(clf_model)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): DistilBertSdpaAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
# ...

# %% [markdown]
# ## Useful classes and methods

# %%
reference = {
    "High-level": ["pipeline"],
    "Tokenizers": ["AutoTokenizer", "encode", "decode", "__call__"],
    "Models": ["AutoModel", "AutoModelForSequenceClassification", "from_pretrained"],
    "Common tasks": ["sentiment-analysis", "text-generation", "translation", "summarization"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
# Out:
# High-level:
# pipeline
#
# Tokenizers:
# AutoTokenizer, encode, decode, __call__
#
# Models:
# AutoModel, AutoModelForSequenceClassification, from_pretrained
#
# Common tasks:
# sentiment-analysis, text-generation, translation, summarization
