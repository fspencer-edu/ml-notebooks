# %% [markdown]
# # AutoGluon Learning Notebook
#
#
# This notebook shows how to use **AutoGluon** for tabular AutoML.
#
# Automatically train models
#
# Features:
#
# automatic model selection
#
# hyperparameter tuning

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# pip install autogluon jupyter
# jupyter notebook
# ```

# %% [markdown]
# ## TabularPredictor

# %%
from autogluon.tabular import TabularPredictor
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris(as_frame=True)
df = iris.frame.rename(columns={"target": "label"})
train = df.sample(frac=0.8, random_state=42)
test = df.drop(train.index)

predictor = TabularPredictor(label="label").fit(train_data=train)
pred = predictor.predict(test)
print(pred.head())
print(predictor.evaluate(test))
# Out:
# /opt/homebrew/anaconda3/envs/mlenv/lib/python3.11/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# No path specified. Models will be saved in: "AutogluonModels/ag-20260315_034605"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.5.0
# Python Version:     3.11.14
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 24.2.0: Fri Dec  6 19:02:41 PST 2024; root:xnu-11215.61.5~2/RELEASE_ARM64_T6030
# CPU Count:          12
# Pytorch Version:    2.9.1
# CUDA Version:       CUDA is not available
# GPU Count:          WARNING: Exception was raised when calculating GPU count (AssertionError)
# Memory Avail:       3.38 GB / 18.00 GB (18.8%)
# Disk Space Avail:   64.72 GB / 460.43 GB (14.1%)
# ...

# %% [markdown]
# ## Useful pieces

# %%
reference = {
    "Core": ["TabularPredictor"],
    "Methods": ["fit", "predict", "evaluate", "leaderboard", "feature_importance"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
# Out:
# Core:
# TabularPredictor
#
# Methods:
# fit, predict, evaluate, leaderboard, feature_importance
