# %% [markdown]
# # Albumentations Learning Notebook
#
#
# This notebook shows how to use **Albumentations** for image augmentation.

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# pip install albumentations opencv-python matplotlib jupyter
# jupyter notebook
# ```

# %% [markdown]
# ## Transforms

# %%
import albumentations as A
import numpy as np

image = np.zeros((128, 128, 3), dtype=np.uint8)
transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.Rotate(limit=30, p=0.5)
])

augmented = transform(image=image)
print(augmented.keys())
print(augmented["image"].shape)
# Out:
# dict_keys(['image'])
# (128, 128, 3)

# %% [markdown]
# ## Useful pieces

# %%
reference = {
    "Core": ["Compose"],
    "Transforms": ["HorizontalFlip", "VerticalFlip", "Rotate", "RandomBrightnessContrast", "Normalize"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
# Out:
# Core:
# Compose
#
# Transforms:
# HorizontalFlip, VerticalFlip, Rotate, RandomBrightnessContrast, Normalize
