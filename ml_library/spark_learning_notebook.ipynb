# %% [markdown]
# # Apache Spark Learning Notebook
#
#
# This notebook shows how to use **PySpark** for distributed DataFrame work.
#
# distributed computation
#
# cluster computing
#
# big data ML

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# pip install pyspark pandas jupyter
# jupyter notebook
# ```

# %% [markdown]
# ## Spark session

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
spark = SparkSession.builder.appName("spark-demo").getOrCreate()
print(spark)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# WARNING: package sun.security.action not in java.base
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/03/14 23:39:53 WARN Utils: Your hostname, Fionas-MacBook-Pro.local, resolves to a loopback address: 127.0.0.1; using 192.168.4.26 instead (on interface en0)
# 26/03/14 23:39:53 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/14 23:39:53 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# WARNING: A terminally deprecated method in sun.misc.Unsafe has been called
# ...

# %% [markdown]
# ## Create DataFrame

# %%
data = [("Fiona", "Toronto", 92), ("Alex", "Montreal", 85), ("Sam", "Toronto", 78)]
df = spark.createDataFrame(data, ["name", "city", "score"])
df.show()
# Out:
# 26/03/14 23:39:58 WARN FileSystem: Cannot load filesystem
# java.util.ServiceConfigurationError: org.apache.hadoop.fs.FileSystem: Provider org.apache.hadoop.fs.viewfs.ViewFileSystem could not be instantiated
# 	at java.base/java.util.ServiceLoader.fail(ServiceLoader.java:552)
# 	at java.base/java.util.ServiceLoader$ProviderImpl.newInstance(ServiceLoader.java:712)
# 	at java.base/java.util.ServiceLoader$ProviderImpl.get(ServiceLoader.java:672)
# 	at java.base/java.util.ServiceLoader$2.next(ServiceLoader.java:1256)
# 	at org.apache.hadoop.fs.FileSystem.loadFileSystems(FileSystem.java:3525)
# 	at org.apache.hadoop.fs.FileSystem.getFileSystemClass(FileSystem.java:3562)
# 	at org.apache.hadoop.fs.FsUrlStreamHandlerFactory.<init>(FsUrlStreamHandlerFactory.java:77)
# 	at org.apache.spark.sql.internal.SharedState$.liftedTree2$1(SharedState.scala:209)
# ...

# %% [markdown]
# ## Select, filter, group

# %%
df.select("name", "score").show()
df.filter(F.col("score") >= 85).show()
df.groupBy("city").agg(F.avg("score").alias("avg_score")).show()
# Out:
# +-----+-----+
# | name|score|
# +-----+-----+
# |Fiona|   92|
# | Alex|   85|
# |  Sam|   78|
# +-----+-----+
#
# +-----+--------+-----+
# | name|    city|score|
# +-----+--------+-----+
# |Fiona| Toronto|   92|
# | Alex|Montreal|   85|
# +-----+--------+-----+
#
# +--------+---------+
# |    city|avg_score|
# +--------+---------+
# | Toronto|     85.0|
# |Montreal|     85.0|
# +--------+---------+

# %% [markdown]
# ## Useful pieces

# %%
reference = {
    "Core": ["SparkSession", "DataFrame"],
    "DataFrame ops": ["select", "filter", "withColumn", "groupBy", "agg", "join", "show"],
    "Functions": ["col", "avg", "sum", "count", "when"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
# Out:
# Core:
# SparkSession, DataFrame
#
# DataFrame ops:
# select, filter, withColumn, groupBy, agg, join, show
#
# Functions:
# col, avg, sum, count, when
