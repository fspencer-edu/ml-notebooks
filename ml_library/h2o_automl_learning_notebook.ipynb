# %% [markdown]
# # H2O AutoML Learning Notebook
#
#
# This notebook shows how to use **H2O AutoML**.

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# pip install h2o jupyter
# jupyter notebook
# ```

# %% [markdown]
# ## Basic AutoML workflow

# %%
import h2o
from h2o.automl import H2OAutoML
from sklearn.datasets import load_iris

h2o.init()

iris = load_iris(as_frame=True)
df = iris.frame.rename(columns={"target": "label"})
hf = h2o.H2OFrame(df)

train, test = hf.split_frame(ratios=[0.8], seed=42)
aml = H2OAutoML(max_models=5, seed=42)
aml.train(y="label", training_frame=train)

print(aml.leaderboard)
pred = aml.leader.predict(test)
pred.head()

# %% [markdown]
# ## Useful pieces

# %%
reference = {
    "Core": ["init", "H2OFrame", "H2OAutoML"],
    "Methods": ["train", "predict", "leaderboard"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
