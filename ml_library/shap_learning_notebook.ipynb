# %% [markdown]
# # SHAP Learning Notebook
#
#
# This notebook shows how to use **SHAP** for model explainability.

# %% [markdown]
# ## Jupyter setup
#
# ```bash
# pip install shap scikit-learn xgboost pandas matplotlib jupyter
# jupyter notebook
# ```

# %% [markdown]
# ## Train model and explain

# %%
import shap
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

data = load_breast_cancer(as_frame=True)
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, random_state=42)

model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

explainer = shap.Explainer(model, X_train)
shap_values = explainer(X_test[:50])

shap.plots.bar(shap_values)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 15
#      12 explainer = shap.Explainer(model, X_train)
#      13 shap_values = explainer(X_test[:50])
# ---> 15 shap.plots.bar(shap_values)
#
# File /opt/homebrew/anaconda3/envs/mlenv/lib/python3.11/site-packages/shap/plots/_bar.py:216, in bar(shap_values, max_display, order, clustering, clustering_cutoff, show_data, ax, show)
#     214 for inds in orig_inds:
#     215     if len(inds) == 1:
# --> 216         feature_names_new.append(feature_names[inds[0]])
#     217     else:
#     218         full_print = " + ".join([feature_names[i] for i in inds])
#
# IndexError: list index out of range

# %% [markdown]
# ## Useful pieces

# %%
reference = {
    "Core": ["Explainer", "TreeExplainer", "KernelExplainer"],
    "Plots": ["plots.bar", "plots.beeswarm", "plots.waterfall"]
}
for k, v in reference.items():
    print("\n" + k + ":")
    print(", ".join(v))
# Out:
# Core:
# Explainer, TreeExplainer, KernelExplainer
#
# Plots:
# plots.bar, plots.beeswarm, plots.waterfall
