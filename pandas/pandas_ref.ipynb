# %% [markdown]
# # pandas Reference

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

print("pandas version:", pd.__version__)
print("numpy version:", np.__version__)
# Out:
# pandas version: 2.3.3
# numpy version: 2.1.3

# %%
# Dataset

data = {
    "student_id": [101, 102, 103, 104, 105, 106],
    "name": ["Fiona", "Alex", "Sam", "Jordan", "Maya", "Noah"],
    "course": ["Python", "Python", "SQL", "ML", "SQL", "ML"],
    "score": [92, 85, 78, 95, np.nan, 88],
    "hours_studied": [12, 9, 7, 15, 6, 11],
    "passed": [True, True, False, True, False, True],
    "city": ["Toronto", "Montreal", "Toronto", "Vancouver", "Toronto", "Montreal"],
    "exam_date": pd.to_datetime(["2026-03-01", "2026-03-01", "2026-03-02", "2026-03-02", "2026-03-03", "2026-03-03"])
}

df = pd.DataFrame(data)
df
# Out:
#    student_id    name  course  score  hours_studied  passed       city  \
# 0         101   Fiona  Python   92.0             12    True    Toronto
# 1         102    Alex  Python   85.0              9    True   Montreal
# 2         103     Sam     SQL   78.0              7   False    Toronto
# 3         104  Jordan      ML   95.0             15    True  Vancouver
# 4         105    Maya     SQL    NaN              6   False    Toronto
# 5         106    Noah      ML   88.0             11    True   Montreal
#
#    exam_date
# 0 2026-03-01
# 1 2026-03-01
# 2 2026-03-02
# 3 2026-03-02
# 4 2026-03-03
# 5 2026-03-03

# %%
# Series vs DF
scores = df["score"]
print("Type of df['score']:", type(scores))
print(scores)

print("Type of df:", type(df))
print(df)
# Out:
# Type of df['score']: <class 'pandas.core.series.Series'>
# 0    92.0
# 1    85.0
# 2    78.0
# 3    95.0
# 4     NaN
# 5    88.0
# Name: score, dtype: float64
# Type of df: <class 'pandas.core.frame.DataFrame'>
#    student_id    name  course  score  hours_studied  passed       city  \
# 0         101   Fiona  Python   92.0             12    True    Toronto
# 1         102    Alex  Python   85.0              9    True   Montreal
# 2         103     Sam     SQL   78.0              7   False    Toronto
# 3         104  Jordan      ML   95.0             15    True  Vancouver
# 4         105    Maya     SQL    NaN              6   False    Toronto
# 5         106    Noah      ML   88.0             11    True   Montreal
#
#    exam_date
# 0 2026-03-01
# 1 2026-03-01
# 2 2026-03-02
# 3 2026-03-02
# 4 2026-03-03
# 5 2026-03-03

# %%
# Inspection
print("Shape:", df.shape)
print("Columns:", df.columns.tolist())
print("Index:", df.index)
print("Dtypes:\n", df.dtypes)
print("Head:", df.head(1))
print("Tail:", df.tail(1))
# Out:
# Shape: (6, 8)
# Columns: ['student_id', 'name', 'course', 'score', 'hours_studied', 'passed', 'city', 'exam_date']
# Index: RangeIndex(start=0, stop=6, step=1)
# Dtypes:
#  student_id                int64
# name                     object
# course                   object
# score                   float64
# hours_studied             int64
# passed                     bool
# city                     object
# exam_date        datetime64[ns]
# dtype: object
# Head:    student_id   name  course  score  hours_studied  passed     city  exam_date
# 0         101  Fiona  Python   92.0             12    True  Toronto 2026-03-01
# Tail:    student_id  name course  score  hours_studied  passed      city  exam_date
# 5         106  Noah     ML   88.0             11    True  Montreal 2026-03-03

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   student_id     6 non-null      int64
#  1   name           6 non-null      object
#  2   course         6 non-null      object
#  3   score          5 non-null      float64
#  4   hours_studied  6 non-null      int64
#  5   passed         6 non-null      bool
#  6   city           6 non-null      object
#  7   exam_date      6 non-null      datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 474.0+ bytes

# %%
df.describe(include="all")
# Out:
#         student_id   name  course      score  hours_studied passed     city  \
# count     6.000000      6       6   5.000000        6.00000      6        6
# unique         NaN      6       3        NaN            NaN      2        3
# top            NaN  Fiona  Python        NaN            NaN   True  Toronto
# freq           NaN      1       2        NaN            NaN      4        3
# mean    103.500000    NaN     NaN  87.600000       10.00000    NaN      NaN
# min     101.000000    NaN     NaN  78.000000        6.00000    NaN      NaN
# 25%     102.250000    NaN     NaN  85.000000        7.50000    NaN      NaN
# 50%     103.500000    NaN     NaN  88.000000       10.00000    NaN      NaN
# 75%     104.750000    NaN     NaN  92.000000       11.75000    NaN      NaN
# max     106.000000    NaN     NaN  95.000000       15.00000    NaN      NaN
# std       1.870829    NaN     NaN   6.580274        3.34664    NaN      NaN
#
#                   exam_date
# count                     6
# unique                  NaN
# top                     NaN
# freq                    NaN
# mean    2026-03-02 00:00:00
# min     2026-03-01 00:00:00
# 25%     2026-03-01 06:00:00
# 50%     2026-03-02 00:00:00
# 75%     2026-03-02 18:00:00
# max     2026-03-03 00:00:00
# std                     NaN

# %%
# Load data
iris_csv = pd.read_csv("../numpy/data/iris.csv")
loaded_csv.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Load data
#       2 iris_csv = pd.read_csv("../numpy/data/iris.csv")
# ----> 3 loaded_csv.head()
#
# NameError: name 'loaded_csv' is not defined

# %%
iris_csv["species"]
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
iris_csv[["sepal_length", "sepal_width", "petal_length", "petal_width"]]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
# Row selection with .loc and .iloc
iris_csv.loc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
iris_csv.loc[0:3, ["sepal_length", "species"]]
# Out:
#    sepal_length species
# 0           5.1  setosa
# 1           4.9  setosa
# 2           4.7  setosa
# 3           4.6  setosa

# %%
iris_csv.iloc(0)

# %%
iris_csv.iloc[0:3, 1:4]
# Out:
#    sepal_width  petal_length  petal_width
# 0          3.5           1.4          0.2
# 1          3.0           1.4          0.2
# 2          3.2           1.3          0.2

# %%
# Boolean filter
df[df["score"] >= 90]
# Out:
#    student_id    name  course  score  hours_studied  passed       city  \
# 0         101   Fiona  Python   92.0             12    True    Toronto
# 3         104  Jordan      ML   95.0             15    True  Vancouver
#
#    exam_date
# 0 2026-03-01
# 3 2026-03-02

# %%
# AND
df[(df["course"] == "Python") & (df["passed"] == True)]
# Out:
#    student_id   name  course  score  hours_studied  passed      city  \
# 0         101  Fiona  Python   92.0             12    True   Toronto
# 1         102   Alex  Python   85.0              9    True  Montreal
#
#    exam_date
# 0 2026-03-01
# 1 2026-03-01

# %%
# IS IN
df[df["city"].isin(["Toronto", "Montreal"])]
# Out:
#    student_id   name  course  score  hours_studied  passed      city  \
# 0         101  Fiona  Python   92.0             12    True   Toronto
# 1         102   Alex  Python   85.0              9    True  Montreal
# 2         103    Sam     SQL   78.0              7   False   Toronto
# 4         105   Maya     SQL    NaN              6   False   Toronto
# 5         106   Noah      ML   88.0             11    True  Montreal
#
#    exam_date
# 0 2026-03-01
# 1 2026-03-01
# 2 2026-03-02
# 4 2026-03-03
# 5 2026-03-03

# %%
# CONTAINS
df[df["name"].str.contains("a", case=False)]
# Out:
#    student_id    name  course  score  hours_studied  passed       city  \
# 0         101   Fiona  Python   92.0             12    True    Toronto
# 1         102    Alex  Python   85.0              9    True   Montreal
# 2         103     Sam     SQL   78.0              7   False    Toronto
# 3         104  Jordan      ML   95.0             15    True  Vancouver
# 4         105    Maya     SQL    NaN              6   False    Toronto
# 5         106    Noah      ML   88.0             11    True   Montreal
#
#    exam_date
# 0 2026-03-01
# 1 2026-03-01
# 2 2026-03-02
# 3 2026-03-02
# 4 2026-03-03
# 5 2026-03-03

# %%
# Sorting
df.sort_values(["course", "score"], ascending=[True, False])
# Out:
#    student_id    name  course  score  hours_studied  passed       city  \
# 3         104  Jordan      ML   95.0             15    True  Vancouver
# 5         106    Noah      ML   88.0             11    True   Montreal
# 0         101   Fiona  Python   92.0             12    True    Toronto
# 1         102    Alex  Python   85.0              9    True   Montreal
# 2         103     Sam     SQL   78.0              7   False    Toronto
# 4         105    Maya     SQL    NaN              6   False    Toronto
#
#    exam_date
# 3 2026-03-02
# 5 2026-03-03
# 0 2026-03-01
# 1 2026-03-01
# 2 2026-03-02
# 4 2026-03-03

# %%
# Missing values
df.isna()
# Out:
#    student_id   name  course  score  hours_studied  passed   city  exam_date
# 0       False  False   False  False          False   False  False      False
# 1       False  False   False  False          False   False  False      False
# 2       False  False   False  False          False   False  False      False
# 3       False  False   False  False          False   False  False      False
# 4       False  False   False   True          False   False  False      False
# 5       False  False   False  False          False   False  False      False

# %%
df.isna().sum()
# Out:
# student_id       0
# name             0
# course           0
# score            1
# hours_studied    0
# passed           0
# city             0
# exam_date        0
# dtype: int64

# %%
df["score"].fillna(df["score"].mean())
# Out:
# 0    92.0
# 1    85.0
# 2    78.0
# 3    95.0
# 4    87.6
# 5    88.0
# Name: score, dtype: float64

# %%
df_filled = df.copy()
df_filled["score"] = df_filled["score"].fillna(df_filled["score"].mean())
df_filled
# Out:
#    student_id    name  course  score  hours_studied  passed       city  \
# 0         101   Fiona  Python   92.0             12    True    Toronto
# 1         102    Alex  Python   85.0              9    True   Montreal
# 2         103     Sam     SQL   78.0              7   False    Toronto
# 3         104  Jordan      ML   95.0             15    True  Vancouver
# 4         105    Maya     SQL   87.6              6   False    Toronto
# 5         106    Noah      ML   88.0             11    True   Montreal
#
#    exam_date
# 0 2026-03-01
# 1 2026-03-01
# 2 2026-03-02
# 3 2026-03-02
# 4 2026-03-03
# 5 2026-03-03

# %%
# Dropped index 4
df.dropna()
# Out:
#    student_id    name  course  score  hours_studied  passed       city  \
# 0         101   Fiona  Python   92.0             12    True    Toronto
# 1         102    Alex  Python   85.0              9    True   Montreal
# 2         103     Sam     SQL   78.0              7   False    Toronto
# 3         104  Jordan      ML   95.0             15    True  Vancouver
# 5         106    Noah      ML   88.0             11    True   Montreal
#
#    exam_date
# 0 2026-03-01
# 1 2026-03-01
# 2 2026-03-02
# 3 2026-03-02
# 5 2026-03-03

# %%
df2 = df.copy()
df2["score_filled"] = df2["score"].fillna(df2["score"].mean())
df2["score_percent"] = df2["score_filled"] / 100
df2["study_level"] = np.where(df2["hours_studied"] >= 10, "High", "Low")
df2
# Out:
#    student_id    name  course  score  hours_studied  passed       city  \
# 0         101   Fiona  Python   92.0             12    True    Toronto
# 1         102    Alex  Python   85.0              9    True   Montreal
# 2         103     Sam     SQL   78.0              7   False    Toronto
# 3         104  Jordan      ML   95.0             15    True  Vancouver
# 4         105    Maya     SQL    NaN              6   False    Toronto
# 5         106    Noah      ML   88.0             11    True   Montreal
#
#    exam_date  score_filled  score_percent study_level
# 0 2026-03-01          92.0          0.920        High
# 1 2026-03-01          85.0          0.850         Low
# 2 2026-03-02          78.0          0.780         Low
# 3 2026-03-02          95.0          0.950        High
# 4 2026-03-03          87.6          0.876         Low
# 5 2026-03-03          88.0          0.880        High

# %%
df2["name_upper"] = df2["name"].str.upper()
df2
# Out:
#    student_id    name  course  score  hours_studied  passed       city  \
# 0         101   Fiona  Python   92.0             12    True    Toronto
# 1         102    Alex  Python   85.0              9    True   Montreal
# 2         103     Sam     SQL   78.0              7   False    Toronto
# 3         104  Jordan      ML   95.0             15    True  Vancouver
# 4         105    Maya     SQL    NaN              6   False    Toronto
# 5         106    Noah      ML   88.0             11    True   Montreal
#
#    exam_date  score_filled  score_percent study_level name_upper
# 0 2026-03-01          92.0          0.920        High      FIONA
# 1 2026-03-01          85.0          0.850         Low       ALEX
# 2 2026-03-02          78.0          0.780         Low        SAM
# 3 2026-03-02          95.0          0.950        High     JORDAN
# 4 2026-03-03          87.6          0.876         Low       MAYA
# 5 2026-03-03          88.0          0.880        High       NOAH

# %%
df2 = df2.drop(columns=["name_upper"])
df2.head()
# Out:
#    student_id    name  course  score  hours_studied  passed       city  \
# 0         101   Fiona  Python   92.0             12    True    Toronto
# 1         102    Alex  Python   85.0              9    True   Montreal
# 2         103     Sam     SQL   78.0              7   False    Toronto
# 3         104  Jordan      ML   95.0             15    True  Vancouver
# 4         105    Maya     SQL    NaN              6   False    Toronto
#
#    exam_date  score_filled  score_percent study_level
# 0 2026-03-01          92.0          0.920        High
# 1 2026-03-01          85.0          0.850         Low
# 2 2026-03-02          78.0          0.780         Low
# 3 2026-03-02          95.0          0.950        High
# 4 2026-03-03          87.6          0.876         Low

# %%
df2.rename(columns={"hours_studied": "hours"})
# Out:
#    student_id    name  course  score  hours  passed       city  exam_date  \
# 0         101   Fiona  Python   92.0     12    True    Toronto 2026-03-01
# 1         102    Alex  Python   85.0      9    True   Montreal 2026-03-01
# 2         103     Sam     SQL   78.0      7   False    Toronto 2026-03-02
# 3         104  Jordan      ML   95.0     15    True  Vancouver 2026-03-02
# 4         105    Maya     SQL    NaN      6   False    Toronto 2026-03-03
# 5         106    Noah      ML   88.0     11    True   Montreal 2026-03-03
#
#    score_filled  score_percent study_level
# 0          92.0          0.920        High
# 1          85.0          0.850         Low
# 2          78.0          0.780         Low
# 3          95.0          0.950        High
# 4          87.6          0.876         Low
# 5          88.0          0.880        High

# %%
df["name"].str.lower()
# Out:
# 0     fiona
# 1      alex
# 2       sam
# 3    jordan
# 4      maya
# 5      noah
# Name: name, dtype: object

# %%
df["course"].str.replace("ML", "Machine Learning")
# Out:
# 0              Python
# 1              Python
# 2                 SQL
# 3    Machine Learning
# 4                 SQL
# 5    Machine Learning
# Name: course, dtype: object

# %%
df["email"] = df["name"].str.lower() + "@example.com"
df[["name", "email"]]
# Out:
#      name               email
# 0   Fiona   fiona@example.com
# 1    Alex    alex@example.com
# 2     Sam     sam@example.com
# 3  Jordan  jordan@example.com
# 4    Maya    maya@example.com
# 5    Noah    noah@example.com

# %%
df["course"].value_counts()
# Out:
# course
# Python    2
# SQL       2
# ML        2
# Name: count, dtype: int64

# %%
print("Unique cities:", df["city"].unique())
print("Number of unique cities:", df["city"].nunique())
# Out:
# Unique cities: ['Toronto' 'Montreal' 'Vancouver']
# Number of unique cities: 3

# %%
# Function
df["hours_studied"].apply(lambda x: x * 2)
# Out:
# 0    24
# 1    18
# 2    14
# 3    30
# 4    12
# 5    22
# Name: hours_studied, dtype: int64

# %%
def grade_label(score):
    if pd.isna(score):
        return "Missing"
    elif score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    else:
        return "D"

df["grade"] = df["score"].apply(grade_label)
df[["name", "score", "grade"]]
# Out:
#      name  score    grade
# 0   Fiona   92.0        A
# 1    Alex   85.0        B
# 2     Sam   78.0        C
# 3  Jordan   95.0        A
# 4    Maya    NaN  Missing
# 5    Noah   88.0        B

# %%
# Aggregations
print("Mean score:", df["score"].mean())
print("Median score:", df["score"].median())
print("Min score:", df["score"].min())
print("Max score:", df["score"].max())
print("Sum of study hours:", df["hours_studied"].sum())
# Out:
# Mean score: 87.6
# Median score: 88.0
# Min score: 78.0
# Max score: 95.0
# Sum of study hours: 60

# %%
# Group by
df.groupby("course")["score"].mean()
# Out:
# course
# ML        91.5
# Python    88.5
# SQL       78.0
# Name: score, dtype: float64

# %%
df.groupby("city")[["score", "hours_studied"]].mean(numeric_only=True)
# Out:
#            score  hours_studied
# city
# Montreal    86.5      10.000000
# Toronto     85.0       8.333333
# Vancouver   95.0      15.000000

# %%
df.groupby(["course", "city"]).agg({
    "score": ["mean", "max"],
    "hours_studied": ["sum", "mean"]
})
# Out:
#                  score       hours_studied
#                   mean   max           sum  mean
# course city
# ML     Montreal   88.0  88.0            11  11.0
#        Vancouver  95.0  95.0            15  15.0
# Python Montreal   85.0  85.0             9   9.0
#        Toronto    92.0  92.0            12  12.0
# SQL    Toronto    78.0  78.0            13   6.5

# %%
# Transform
df["course_avg_score"] = df.groupby("course")["score"].transform("mean")
df[["name", "course", "score", "course_avg_score"]]
# Out:
#      name  course  score  course_avg_score
# 0   Fiona  Python   92.0              88.5
# 1    Alex  Python   85.0              88.5
# 2     Sam     SQL   78.0              78.0
# 3  Jordan      ML   95.0              91.5
# 4    Maya     SQL    NaN              78.0
# 5    Noah      ML   88.0              91.5

# %%
attendance = pd.DataFrame({
    "student_id": [101, 102, 103, 104, 107],
    "attendance_rate": [0.95, 0.88, 0.76, 0.99, 0.80]
})
merged = pd.merge(df, attendance, on="student_id", how="left")
display(attendance)
display(merged)
# Out:
#    student_id  attendance_rate
# 0         101             0.95
# 1         102             0.88
# 2         103             0.76
# 3         104             0.99
# 4         107             0.80
#    student_id    name  course  score  hours_studied  passed       city  \
# 0         101   Fiona  Python   92.0             12    True    Toronto
# 1         102    Alex  Python   85.0              9    True   Montreal
# 2         103     Sam     SQL   78.0              7   False    Toronto
# 3         104  Jordan      ML   95.0             15    True  Vancouver
# 4         105    Maya     SQL    NaN              6   False    Toronto
# 5         106    Noah      ML   88.0             11    True   Montreal
#
#    exam_date               email    grade  course_avg_score  attendance_rate
# 0 2026-03-01   fiona@example.com        A              88.5             0.95
# 1 2026-03-01    alex@example.com        B              88.5             0.88
# 2 2026-03-02     sam@example.com        C              78.0             0.76
# 3 2026-03-02  jordan@example.com        A              91.5             0.99
# 4 2026-03-03    maya@example.com  Missing              78.0              NaN
# 5 2026-03-03    noah@example.com        B              91.5              NaN

# %%
# Out:
#    student_id    name  course  score  hours_studied  passed       city  \
# 0         101   Fiona  Python   92.0             12    True    Toronto
# 1         102    Alex  Python   85.0              9    True   Montreal
# 2         103     Sam     SQL   78.0              7   False    Toronto
# 3         104  Jordan      ML   95.0             15    True  Vancouver
# 4         105    Maya     SQL    NaN              6   False    Toronto
# 5         106    Noah      ML   88.0             11    True   Montreal
#
#    exam_date               email    grade  course_avg_score  attendance_rate
# 0 2026-03-01   fiona@example.com        A              88.5             0.95
# 1 2026-03-01    alex@example.com        B              88.5             0.88
# 2 2026-03-02     sam@example.com        C              78.0             0.76
# 3 2026-03-02  jordan@example.com        A              91.5             0.99
# 4 2026-03-03    maya@example.com  Missing              78.0              NaN
# 5 2026-03-03    noah@example.com        B              91.5              NaN

# %%
left = pd.DataFrame({"id": [1, 2, 3], "value_left": ["A", "B", "C"]})
right = pd.DataFrame({"id": [2, 3, 4], "value_right": ["X", "Y", "Z"]})

print("Inner join:")
display(pd.merge(left, right, on="id", how="inner"))

print("Left join:")
display(pd.merge(left, right, on="id", how="left"))

print("Outer join:")
display(pd.merge(left, right, on="id", how="outer"))
# Out:
# Inner join:
#    id value_left value_right
# 0   2          B           X
# 1   3          C           Y
# Left join:
#    id value_left value_right
# 0   1          A         NaN
# 1   2          B           X
# 2   3          C           Y
# Outer join:
#    id value_left value_right
# 0   1          A         NaN
# 1   2          B           X
# 2   3          C           Y
# 3   4        NaN           Z

# %%
# concatenate
part1 = df.iloc[:3]
part2 = df.iloc[3:]

pd.concat([part1, part2], axis=0)
# Out:
#    student_id    name  course  score  hours_studied  passed       city  \
# 0         101   Fiona  Python   92.0             12    True    Toronto
# 1         102    Alex  Python   85.0              9    True   Montreal
# 2         103     Sam     SQL   78.0              7   False    Toronto
# 3         104  Jordan      ML   95.0             15    True  Vancouver
# 4         105    Maya     SQL    NaN              6   False    Toronto
# 5         106    Noah      ML   88.0             11    True   Montreal
#
#    exam_date               email    grade  course_avg_score
# 0 2026-03-01   fiona@example.com        A              88.5
# 1 2026-03-01    alex@example.com        B              88.5
# 2 2026-03-02     sam@example.com        C              78.0
# 3 2026-03-02  jordan@example.com        A              91.5
# 4 2026-03-03    maya@example.com  Missing              78.0
# 5 2026-03-03    noah@example.com        B              91.5

# %%
# Pivot tables
pd.pivot_table(
    df,
    values="hours_studied",
    index="course",
    columns="city",
    aggfunc="mean"
)
# Out:
# city    Montreal  Toronto  Vancouver
# course
# ML          11.0      NaN       15.0
# Python       9.0     12.0        NaN
# SQL          NaN      6.5        NaN

# %%
# Melt / Long format
wide_df = pd.DataFrame({
    "student": ["Fiona", "Alex"],
    "math": [90, 80],
    "science": [95, 85]
})

wide_df
# Out:
#   student  math  science
# 0   Fiona    90       95
# 1    Alex    80       85

# %%
pd.melt(wide_df, id_vars="student", var_name="subject", value_name="score")
# Out:
#   student  subject  score
# 0   Fiona     math     90
# 1    Alex     math     80
# 2   Fiona  science     95
# 3    Alex  science     85

# %%
# Dates and time series
dates = pd.date_range(start="2026-03-01", periods=6, freq="D")
ts = pd.Series([10, 12, 9, 15, 14, 18], index=dates)
ts
# Out:
# 2026-03-01    10
# 2026-03-02    12
# 2026-03-03     9
# 2026-03-04    15
# 2026-03-05    14
# 2026-03-06    18
# Freq: D, dtype: int64

# %%
ts.rolling(3).mean()
# Out:
# 2026-03-01          NaN
# 2026-03-02          NaN
# 2026-03-03    10.333333
# 2026-03-04    12.000000
# 2026-03-05    12.666667
# 2026-03-06    15.666667
# Freq: D, dtype: float64

# %%
# Duplicates
dup_df = pd.DataFrame({
    "name": ["A", "A", "B", "C", "C"],
    "score": [1, 1, 2, 3, 3]
})

print("Duplicates:")
display(dup_df.duplicated())

print("\nWithout duplicates:")
display(dup_df.drop_duplicates())
# Out:
# Duplicates:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# dtype: bool
# Without duplicates:
#   name  score
# 0    A      1
# 2    B      2
# 3    C      3

# %%
# Index operations

indexed = df.set_index("student_id")
display(indexed)
# Out:
#               name  course  score  hours_studied  passed       city  \
# student_id
# 101          Fiona  Python   92.0             12    True    Toronto
# 102           Alex  Python   85.0              9    True   Montreal
# 103            Sam     SQL   78.0              7   False    Toronto
# 104         Jordan      ML   95.0             15    True  Vancouver
# 105           Maya     SQL    NaN              6   False    Toronto
# 106           Noah      ML   88.0             11    True   Montreal
#
#             exam_date               email    grade  course_avg_score
# student_id
# 101        2026-03-01   fiona@example.com        A              88.5
# 102        2026-03-01    alex@example.com        B              88.5
# 103        2026-03-02     sam@example.com        C              78.0
# 104        2026-03-02  jordan@example.com        A              91.5
# 105        2026-03-03    maya@example.com  Missing              78.0
# 106        2026-03-03    noah@example.com        B              91.5

# %%
display(indexed.loc[101])
# Out:
# name                              Fiona
# course                           Python
# score                              92.0
# hours_studied                        12
# passed                             True
# city                            Toronto
# exam_date           2026-03-01 00:00:00
# email                 fiona@example.com
# grade                                 A
# course_avg_score                   88.5
# Name: 101, dtype: object

# %%
indexed.reset_index().head()
# Out:
#    student_id    name  course  score  hours_studied  passed       city  \
# 0         101   Fiona  Python   92.0             12    True    Toronto
# 1         102    Alex  Python   85.0              9    True   Montreal
# 2         103     Sam     SQL   78.0              7   False    Toronto
# 3         104  Jordan      ML   95.0             15    True  Vancouver
# 4         105    Maya     SQL    NaN              6   False    Toronto
#
#    exam_date               email    grade  course_avg_score
# 0 2026-03-01   fiona@example.com        A              88.5
# 1 2026-03-01    alex@example.com        B              88.5
# 2 2026-03-02     sam@example.com        C              78.0
# 3 2026-03-02  jordan@example.com        A              91.5
# 4 2026-03-03    maya@example.com  Missing              78.0

# %%
# query
df.query("hours_studied >= 10 and passed == True")
# Out:
#    student_id    name  course  score  hours_studied  passed       city  \
# 0         101   Fiona  Python   92.0             12    True    Toronto
# 3         104  Jordan      ML   95.0             15    True  Vancouver
# 5         106    Noah      ML   88.0             11    True   Montreal
#
#    exam_date               email grade  course_avg_score
# 0 2026-03-01   fiona@example.com     A              88.5
# 3 2026-03-02  jordan@example.com     A              91.5
# 5 2026-03-03    noah@example.com     B              91.5

# %%
# sampling
df.sample(3, random_state=42)
# Out:
#    student_id   name  course  score  hours_studied  passed      city  \
# 0         101  Fiona  Python   92.0             12    True   Toronto
# 1         102   Alex  Python   85.0              9    True  Montreal
# 5         106   Noah      ML   88.0             11    True  Montreal
#
#    exam_date              email grade  course_avg_score
# 0 2026-03-01  fiona@example.com     A              88.5
# 1 2026-03-01   alex@example.com     B              88.5
# 5 2026-03-03   noah@example.com     B              91.5

# %%
# export
import os

os.makedirs("./data", exist_ok=True)
df.to_csv("./data/students_export.csv", index=False)
df.to_json("./data/students_export.json", orient="records", indent=2)

print("Saved:")
print("- pandas_data/students_export.csv")
print("- pandas_data/students_export.json")
# Out:
# Saved:
# - pandas_data/students_export.csv
# - pandas_data/students_export.json

# %%
# Plotting with plt
df["hours_studied"].plot(kind="bar", figsize=(8, 4), title="Hours Studied")
plt.xlabel("Row index")
plt.ylabel("Hours")
plt.show()

# %%
df["score"].plot(kind="hist", bins=5, figsize=(8, 4), title="Score Distribution")
plt.xlabel("Score")
plt.show()

# %%
public_pd_names = [name for name in dir(pd) if not name.startswith("_")]
print("Some public names in pandas:")
print(public_pd_names[:200])
print("\nTotal shown:", len(public_pd_names))
# Out:
# Some public names in pandas:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt8Dtype', 'annotations', 'api', 'array', 'arrays', 'bdate_range', 'compat', 'concat', 'core', 'crosstab', 'cut', 'date_range', 'describe_option', 'errors', 'eval', 'factorize', 'from_dummies', 'get_dummies', 'get_option', 'infer_freq', 'interval_range', 'io', 'isna', 'isnull', 'json_normalize', 'lreshape', 'melt', 'merge', 'merge_asof', 'merge_ordered', 'notna', 'notnull', 'offsets', 'option_context', 'options', 'pandas', 'period_range', 'pivot', 'pivot_table', 'plotting', 'qcut', 'read_clipboard', 'read_csv', 'read_excel', 'read_feather', 'read_fwf', 'read_gbq', 'read_hdf', 'read_html', 'read_json', 'read_orc', 'read_parquet', 'read_pickle', 'read_sas', 'read_spss', 'read_sql', 'read_sql_query', 'read_sql_table', 'read_stata', 'read_table', 'read_xml', 'reset_option', 'set_eng_float_format', 'set_option', 'show_versions', 'test', 'testing', 'timedelta_range', 'to_datetime', 'to_numeric', 'to_pickle', 'to_timedelta', 'tseries', 'unique', 'util', 'value_counts', 'wide_to_long']
#
# Total shown: 119
